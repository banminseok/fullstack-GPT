# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(
    # model_name="gpt-5-nano",
    model_name="gpt-3.5-turbo",
    temperature=0.1,
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ],
)

poem_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            (
                "너는 프로그램밍을 하는 개발자 이다. "
                "그리고 부업으로 시를 쓰는 시인이다."
                "좋아하는 시인은 하상욱, 김소연, 나희덕,백아온,윤동주 등이 있다"
                "그중 하상욱의 서울시 시집을 좋아한다."
            ),
        ),
        (
            "human",
            (
                "프로그래밍 언어인 {programLanguage}에 대한 시를"
                " 써주세요(3연으로 구성, 멋진 제목도 있어야함)."
            ),
        ),
    ]
)
poem_chain = poem_prompt | chat

desc_chef_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            (
                "당신은 문학 평론가 입니다."
                "주로 시를 평론하고, 고등학교에서 국어로 시를 가르칩니다."
                "학생들에게 수능 공부를 위해 시를 분석 하고 설명합니다."
            ),
        ),
        (
            "human",
            (
                "아래는 내가 쓴 시인데, 쉽게 알아 들을 정도로 설명하고 분석 해줘"
                "[시 제목] , 줄바꿈 2번 하고  설명헤줘"
                "{poem} "
            ),
        ),
    ]
)

desc_chain = desc_chef_prompt | chat

final_chain = {"poem": poem_chain} | desc_chain

final_chain.invoke({"programLanguage": "python"})
# Out:
# **코드의 노래**
#
# 파이썬으로 시작한 나의 여정
# 알고리즘을 춤추듯 코딩해
# 세상을 바꾸는 그 순간을 꿈꾼다
#
# 데이터의 흐름을 따라가는
# 함수와 모듈이 노래하는
# 컴퓨터의 세계, 나만의 작은 우주
#
# **(제목: 코드의 노래)****시 제목: 코드의 노래**
#
# 이 시는 파이썬이라는 프로그래밍 언어를 통해 시작된 저자의 여정을 담고 있습니다. 저자는 알고리즘을 마치 춤을 추는 것처럼 코딩하며, 세상을 변화시키는 순간을 꿈꾸고 있습니다. 데이터의 흐름을 따라가며 함수와 모듈이 노래하는 모습을 상상하며, 컴퓨터의 세계가 자신만의 작은 우주가 되는 것을 느낍니다.
#
# 이 시는 기술과 예술이 만나는 지점을 표현하고 있습니다. 프로그래밍 언어를 사용하여 새로운 것을 창조하고, 세상을 바꾸는 힘을 꿈꾸는 저자의 열정이 느껴집니다. 또한, 컴퓨터와의 소통을 통해 자신만의 세계를 창조하는 과정을 은유적으로 표현하고 있습니다. 이 시를 통해 기술적인 분야에서도 예술적인 영감을 얻을 수 있다는 메시지를 전달하고 있습니다.
# AIMessageChunk(content='**시 제목: 코드의 노래**\n\n이 시는 파이썬이라는 프로그래밍 언어를 통해 시작된 저자의 여정을 담고 있습니다. 저자는 알고리즘을 마치 춤을 추는 것처럼 코딩하며, 세상을 변화시키는 순간을 꿈꾸고 있습니다. 데이터의 흐름을 따라가며 함수와 모듈이 노래하는 모습을 상상하며, 컴퓨터의 세계가 자신만의 작은 우주가 되는 것을 느낍니다.\n\n이 시는 기술과 예술이 만나는 지점을 표현하고 있습니다. 프로그래밍 언어를 사용하여 새로운 것을 창조하고, 세상을 바꾸는 힘을 꿈꾸는 저자의 열정이 느껴집니다. 또한, 컴퓨터와의 소통을 통해 자신만의 세계를 창조하는 과정을 은유적으로 표현하고 있습니다. 이 시를 통해 기술적인 분야에서도 예술적인 영감을 얻을 수 있다는 메시지를 전달하고 있습니다.')
