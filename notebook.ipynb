# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(
    model_name="gpt-5-nano",
    temperature=1,
    streaming=True,
    callbacks=[
        StreamingStdOutCallbackHandler(),
    ],
)

chef_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            (
                "You are a world-class international chef. You create easy to"
                " follow recipies for any type of cuisine with easy to find"
                " ingredients.Please reply in Korean."
            ),
        ),
        ("human", "I want to cook {cuisine} food."),
    ]
)

chef_chain = chef_prompt | chat

veg_chef_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            (
                "You are a vegetarian chef specialized on making traditional"
                " recipes vegetarian. You find alternative ingredients and"
                " explain their preparation. You don't radically modify the"
                " recipe. If there is no alternative for a food just say you"
                " don't know how to recipe it.Please reply in Korean."
            ),
        ),
        ("human", "{recipe}"),
    ]
)

veg_chain = veg_chef_prompt | chat

final_chain = {"recipe": chef_chain} | veg_chain

final_chain.invoke({"cuisine": "indian"})
# Out:
# 멋지네요! 인도 요리 시작하기에 딱 좋은 쉬운 레시피를 하나 먼저 드릴게요. 초간단 달 타다카(Dal Tadka)로 볶음 밥과 난과 함께 맛있게 즐길 수 있어요.
#
# 초간단 달 타다카 (Dal Tadka) 2-3인분
# 소요 시간: 약 30분
#
# 재료
# - 렌틸콩( Masoor dal) 1컵
# - 물 3컵
# - 소금 1/2 작은술(맛에 맞게 조절)
# - 양파 1개, 다진 것
# - 마늘 2쪽, 다진 것
# - 생강 1 작은술, 다진 것
# - 토마토 1개, 다진 것(또는 토마토 퓨레 1/2컵)
# - 식용유 또는 식물성 기름 2큰술
# - 커민씨 1 작은술
# - 겨자씨 1/2 작은술
# - 강황가루 1/4 작은술
# - 고춧가루나 카레 파우더 1/2 작은술(매운 정도에 따라 양 조절)
# - 고수잎 약간(장식용)
# - 레몬주스 약간(선택)
#
# 조리 방법
# 1) 렌틸콩을 흐르는 물에 씻은 뒤 15–20분간 불려 준비합니다. 냄비에 렌틸콩과 물, 소금을 넣고 중불로 15–20분 정도 끓여 부드럽게 익히되, 필요하면 물을 조금 더 추가합니다.
# 2) 다른 팬에 기름을 두르고 중불에서 커민씨를 30초 정도 볶아 향을 냅니다. 그다음 겨자씨를 넣어 소리가 날 때까지만 볶습니다.
# 3) 양파를 넣어 황금빛이 날 때까지 5–7분 볶습니다. 마늘과 생강을 넣고 1–2분 더 볶아 향을 낸 뒤 토마토를 넣고 3–4분 정도 끓여 소스가 걸쭉해지도록 합니다.
# 4) 강황가루와 고춧가루(또는 카레 파우더)를 넣고 1분 정도 더 볶아 향신료 맛을 살려줍니다.
# 5) 삶아 둔 렌틸콩을 팬에 넣고 잘 섞은 뒤 물이 너무 많지 않다면 약간의 물을 더해 농도를 맞춥니다. 5–10분 더 끓여 간을 맞춥니다.
# 6) 불에서 내리고, 고수잎과 원하면 레몬주스로 마무리합니다.
#
# 팁
# - 집에 건조 렌틸콩이 없으면 캔 병아리콩처럼 미리 삶은 것도 사용해도 좋고, 이 레시피를 차나 마살라로 바꿀 때도 응용 가능해요.
# - 매운 정도를 줄이고 싶으면 고춧가루를 빼거나 아주 소량만 사용하고, 대신 커민과 토마토의 달콤함으로 맛을 살려보세요.
# - 밥이나 난(난 빵)과 함께 내면 더 맛있습니다.
#
# 다른 옵션이 필요하시면, 채식만 가능하신지, 살코기 들어간 요리도 원하시는지, 매운 정도 선호도(매운맛 약간/중간/매운맛 강)를 알려 주세요. 바로 맞춤 레시피로 드릴게요.멋진 레시피네요! 이 달 타다카는 이미 채식에 적합하고 맛도 좋아요. 아래에 대체 재료와 팁을 정리해 두었어요. 필요하신 방향으로 더 맞춤해 드릴게요.
#
# 대체 재료 및 팁
# - 렌틸콩 대체
#   - 같은 달의 다른 렌틸콩(예: 노란 콩 달)으로도 가능하지만, 익는 시간이 달라질 수 있어 물 양과 시간 조절이 필요합니다.
#   - 건조 렌틸콩이 없으면 미리 삶은 렌틸콩이나 캔 렌틸콩(물기 빼고 사용)으로 대체해도 맛은 비슷합니다.
#   - 병아리콩을 이미 삶아 두었다면 2차 가열 단계에서 병아리콩으로도 충분히 어울려요.
# - 토마토 대체
#   - 토마토가 없으면 토마토 퓌레 1/2컵 대신 토마토 페이스트 1큰술 + 물 1/4컵 정도로 희석해 사용해도 좋습니다.
#   - 토마토 소스 1/2컵도 사용 가능하고, 농도가 너무 걸쭉하면 물을 조금 더 추가하세요.
# - 기름 및 지방
#   - 식물성 기름은 포도씨유, 해바라기유, 카놀라유 중 아무거나 사용 가능.
#   - 버터 풍미를 원하면 식물성 버터를 소량 더해도 맛이 풍부해집니다. 다만 순수 채식을 유지하려면 버터 대신 식물성 기름 권장.
# - 향신료 대체
#   - 커민씨가 없으면 커민 가루 1/2 작은술로 대신해도 됩니다. 향을 살리려면 기름에 씨를 살짝 볶아 향을 내는 방식을 유지하는 것이 좋습니다.
#   - 겨자씨가 없으면 생략해도 무방합니다. 필요 시 흑깨를 소량 뿌려도 색감과 풍미에 약간의 차이가 납니다.
#   - 강황가루는 꼭 넣는 것이 좋지만 없으면 생략해도 맛에 큰 차이가 없고, 대신 카레 파우더를 아주 소량 섞어도 색과 향을 살릴 수 있습니다.
#   - 고춧가루 대신 파프리카 가루를 사용하면 색상을 유지하면서 매운맛은 줄일 수 있습니다. 아주 매운 맛을 원하면 카레 파우더를 소량 추가해도 좋습니다.
# - 매운 정도 조절
#   - 매운맛 약간: 고춧가루 1/4 작은술 정도.
#   - 중간: 레시피대로 1/2 작은술 정도.
#   - 매운맛 강하게: 고춧가루를 3/4 작은술 정도 또는 카레 파우더를 약간 더 추가.
# - 고수잎/고명
#   - 고수잎이 없으면 대체로 생략해도 무난합니다. 색감을 원하면 파슬리로 대체해도 되고, 없으면 그냥 마무리해도 좋아요.
# - 산미
#   - 레몬주스는 취향에 따라 선택적으로 넣으세요. 원하면 요리 마지막에 한두 방울만 뿌려 산미를 유지하는 것이 좋습니다.
#
# 요청하시는 맞춤 옵션이 있나요?
# - 매운 맛 선호도(약간/중간/강)와 채식 여부(완전 채식 유지 여부: 예: 비건으로만 진행) 등을 알려 주시면, 위의 대체 재료를 반영해 바로 맞춤 버전의 Dal Tadka 레시피로 정리해 드릴게요.
# - 또는 특정 재료가 없을 때 바로 적용 가능한 구체적인 대체 조합이 필요하시면 말씀해 주세요.
# AIMessageChunk(content='멋진 레시피네요! 이 달 타다카는 이미 채식에 적합하고 맛도 좋아요. 아래에 대체 재료와 팁을 정리해 두었어요. 필요하신 방향으로 더 맞춤해 드릴게요.\n\n대체 재료 및 팁\n- 렌틸콩 대체\n  - 같은 달의 다른 렌틸콩(예: 노란 콩 달)으로도 가능하지만, 익는 시간이 달라질 수 있어 물 양과 시간 조절이 필요합니다.\n  - 건조 렌틸콩이 없으면 미리 삶은 렌틸콩이나 캔 렌틸콩(물기 빼고 사용)으로 대체해도 맛은 비슷합니다.\n  - 병아리콩을 이미 삶아 두었다면 2차 가열 단계에서 병아리콩으로도 충분히 어울려요.\n- 토마토 대체\n  - 토마토가 없으면 토마토 퓌레 1/2컵 대신 토마토 페이스트 1큰술 + 물 1/4컵 정도로 희석해 사용해도 좋습니다.\n  - 토마토 소스 1/2컵도 사용 가능하고, 농도가 너무 걸쭉하면 물을 조금 더 추가하세요.\n- 기름 및 지방\n  - 식물성 기름은 포도씨유, 해바라기유, 카놀라유 중 아무거나 사용 가능.\n  - 버터 풍미를 원하면 식물성 버터를 소량 더해도 맛이 풍부해집니다. 다만 순수 채식을 유지하려면 버터 대신 식물성 기름 권장.\n- 향신료 대체\n  - 커민씨가 없으면 커민 가루 1/2 작은술로 대신해도 됩니다. 향을 살리려면 기름에 씨를 살짝 볶아 향을 내는 방식을 유지하는 것이 좋습니다.\n  - 겨자씨가 없으면 생략해도 무방합니다. 필요 시 흑깨를 소량 뿌려도 색감과 풍미에 약간의 차이가 납니다.\n  - 강황가루는 꼭 넣는 것이 좋지만 없으면 생략해도 맛에 큰 차이가 없고, 대신 카레 파우더를 아주 소량 섞어도 색과 향을 살릴 수 있습니다.\n  - 고춧가루 대신 파프리카 가루를 사용하면 색상을 유지하면서 매운맛은 줄일 수 있습니다. 아주 매운 맛을 원하면 카레 파우더를 소량 추가해도 좋습니다.\n- 매운 정도 조절\n  - 매운맛 약간: 고춧가루 1/4 작은술 정도.\n  - 중간: 레시피대로 1/2 작은술 정도.\n  - 매운맛 강하게: 고춧가루를 3/4 작은술 정도 또는 카레 파우더를 약간 더 추가.\n- 고수잎/고명\n  - 고수잎이 없으면 대체로 생략해도 무난합니다. 색감을 원하면 파슬리로 대체해도 되고, 없으면 그냥 마무리해도 좋아요.\n- 산미\n  - 레몬주스는 취향에 따라 선택적으로 넣으세요. 원하면 요리 마지막에 한두 방울만 뿌려 산미를 유지하는 것이 좋습니다.\n\n요청하시는 맞춤 옵션이 있나요?\n- 매운 맛 선호도(약간/중간/강)와 채식 여부(완전 채식 유지 여부: 예: 비건으로만 진행) 등을 알려 주시면, 위의 대체 재료를 반영해 바로 맞춤 버전의 Dal Tadka 레시피로 정리해 드릴게요.\n- 또는 특정 재료가 없을 때 바로 적용 가능한 구체적인 대체 조합이 필요하시면 말씀해 주세요.')
