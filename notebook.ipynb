# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(model_name="gpt-5-nano", temperature=1, streaming=True, callbacks=[
    StreamingStdOutCallbackHandler(),
])

chef_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a world-class international chef. You create easy to follow recipies for any type of cuisine with easy to find ingredients."),
    ("human", "I want to cook {cuisine} food."),
])

chef_chain = chef_prompt | chat

veg_chef_prompt = ChatPromptTemplate.from_messages([
   ("system", "You are a vegetarian chef specialized on making traditional recipes vegetarian. You find alternative ingredients and explain their preparation. You don't radically modify the recipe. If there is no alternative for a food just say you don't know how to recipe it."), 
   ("human", "{recipe}"),
])

veg_chain = veg_chef_prompt | chat

final_chain = {"recipe":chef_chain} | veg_chain

final_chain.invoke({"cuisine":"indian"})
# Out:
# Fantastic! Indian food is wonderfully flavorful and surprisingly easy to make at home. Here are three beginner-friendly options using common, easy-to-find ingredients. Tell me which one you’d like to start with (or I can tailor to your dietary needs).
#
# 1) Chana Masala (Chickpea Curry) — vegan, pantry-friendly
#  Serves: 4
#
#  Ingredients
#  - 1 tablespoon oil
#  - 1 medium onion, finely chopped
#  - 2 cloves garlic, minced
#  - 1 inch fresh ginger, grated
#  - 1-2 green chilies, optional
#  - 1 teaspoon ground cumin
#  - 1 teaspoon ground coriander
#  - 1/2 teaspoon turmeric
#  - 1/2 teaspoon garam masala
#  - 1/2 teaspoon chili powder (adjust to taste)
#  - 1 can (400 g) chickpeas, drained and rinsed
#  - 1 cup crushed tomatoes (or 2 fresh tomatoes, chopped)
#  - Salt to taste
#  - Fresh cilantro and a squeeze of lemon to finish
#
#  Steps
#  1) Heat oil in a pan over medium heat. Sauté onion until soft and translucent, about 5 minutes. Add garlic and ginger; cook 1 minute more.
#  2) Add green chilies (if using) and all spices. Stir 30 seconds until fragrant.
#  3) Add tomatoes; cook 5–7 minutes until the sauce thickens slightly.
#  4) Stir in chickpeas and about 1/4 cup water. Simmer 10–15 minutes to meld flavors. Season with salt.
#  5) Finish with cilantro and a squeeze of lemon. Serve with basmati rice or naan.
#
#  Tips
#  - For extra depth, toast the spices in the oil for 30 seconds before adding the onions.
#  - If you like smoother sauce, blend lightly with a spoon or masher a few chickpeas.
#
# 2) Paneer Bhurji (Scrambled Paneer) — quick, protein-packed
#  Serves: 2–3
#
#  Ingredients
#  - 200–250 g paneer (Indian cottage cheese), crumbled
#  - 1 tablespoon oil
#  - 1 small onion, finely chopped
#  - 1 tomato, finely chopped
#  - 1–2 green chilies, optional
#  - 1/2 teaspoon cumin seeds
#  - 1/2 teaspoon turmeric
#  - 1 teaspoon garam masala
#  - Salt to taste
#  - Fresh cilantro to finish
#
#  Steps
#  1) Heat oil in a pan. Add cumin seeds; when they crackle, add onion and chilies. Sauté until onion is soft.
#  2) Add tomato; cook 2–3 minutes until it’s soft.
#  3) Stir in turmeric and garam masala. Add paneer; mix well and cook 2–3 minutes until paneer is heated through and slightly coated with spices.
#  4) Season with salt. Garnish with cilantro. Serve with roti, naan, or rice.
#
#  Tips
#  - If you want a saucier version, add a splash of water and cook a bit longer.
#  - For extra creaminess, add a spoon of yogurt at the end (optional).
#
# 3) Simple Chicken Curry (quick weeknight curry)
#  Serves: 4
#
#  Ingredients
#  - 500 g chicken (thighs preferred for juiciness), cut into bite-sized pieces
#  - 1 tablespoon oil
#  - 1 medium onion, finely chopped
#  - 2 cloves garlic, minced
#  - 1 inch ginger, grated
#  - 1–2 tablespoons curry powder or garam masala (start with 1 tablespoon and adjust)
#  - 1/2 teaspoon turmeric
#  - 1 can (400 g) crushed tomatoes or 2 fresh tomatoes, chopped
#  - 1/2 cup water or chicken stock
#  - Salt to taste
#  - Optional: 2 tablespoons cream or yogurt to finish
#
#  Steps
#  1) In a large pan, brown the chicken pieces in oil over medium-high heat. Remove and set aside.
#  2) In the same pan, sauté onion until soft. Add garlic and ginger; cook 1 minute.
#  3) Add curry powder (or garam masala) and turmeric; stir 30 seconds.
#  4) Add tomatoes and water/stock. Return chicken to pan; simmer 15–20 minutes until chicken is cooked through and sauce thickens.
#  5) If using, stir in cream or yogurt off the heat. Season with salt. Serve with rice or naan.
#
#  Quick tips for all Indian cooking
#  - Build a spice basics pantry: cumin, coriander, turmeric, garam masala. If you can, toast whole spices briefly in oil to release extra aroma.
#  - Use aromatics: onion, garlic, ginger are your best friends for depth of flavor.
#  - Balance with acidity: a little lemon juice or a toast of yogurt can brighten dishes.
#  - Sides: basmati rice, naan, or roti, plus a simple cucumber-mint yogurt raita.
#
# Would you like me to tailor one of these to your spice level, dietary needs (vegetarian, vegan, dairy-free, gluten-free), or what you already have in your kitchen? I can also give you a single, ultra-simple 30-minute plan with exact measurements for your first attempt.Love this lineup. I can tailor any of these to your dietary needs (vegetarian, vegan, dairy-free, gluten-free) and spice level, and I can give you a fast 30-minute plan with exact measurements. Since you’re focusing on vegetarian options, here are quick, ready-to-go picks from your list, plus a simple adaptation if you want a vegan version of Paneer Bhurji.
#
# Best vegetarian fits from your list
# - Chana Masala (Chickpea Curry) — vegan by default, gluten-free if your pantry labels are clean. Great for a straight-up flavorful, pantry-friendly meal.
# - Paneer Bhurji (Scrambled Paneer) — vegetarian. If you want dairy-free, I can show you a gentle substitution that keeps the technique and texture similar.
#
# Vegetarian adaptations and quick swaps
# - Dairy-free / vegan option for Paneer Bhurji:
#   - Substitute paneer with crumbled firm tofu (same amount, 200–250 g). Sauté with the onion and spices; the texture will be slightly softer but still satisfying.
#   - Omit yogurt or cream. If you want extra creaminess, you can stir in a little non-dairy yogurt or a spoon of cashew cream at the end.
#
# - If you want to keep it fully vegetarian but lean toward a “meatier” curry (without chicken):
#   - You can swap chicken in the Simple Chicken Curry for chickpeas or potatoes and add extra vegetables (cauliflower, peas). It keeps the same curry base, just plant-based.
#
# Would you like me to tailor one of these to your spice level, any dietary needs, or ingredients you already have? I can also give you a single ultra-simple 30-minute plan with exact measurements for your first attempt.
#
# Ultra-simple 30-minute plan: Chana Masala (vegan, serves 4)
# - Ingredients
#   - 1 tablespoon oil
#   - 1 small onion, finely chopped
#   - 2 cloves garlic, minced
#   - 1 inch fresh ginger, grated
#   - 1–2 green chilies, optional
#   - 1 teaspoon ground cumin
#   - 1 teaspoon ground coriander
#   - 1/2 teaspoon turmeric
#   - 1/2 teaspoon garam masala
#   - 1/2 teaspoon chili powder (adjust to taste)
#   - 1 can (400 g) chickpeas, drained and rinsed
#   - 1 cup crushed tomatoes (or 2 fresh tomatoes, chopped)
#   - Salt to taste
#   - Fresh cilantro and a squeeze of lemon to finish
#   - 1/4 cup water (more as needed)
# - Steps and timing (about 30 minutes total)
#   0:00 Prep: chop onion, mince garlic, grate ginger, rinse chickpeas.
#   0:05 Sauté: Heat oil in a pan over medium heat. Add onion; cook until soft (about 5 minutes). Add garlic and ginger; cook 1 minute.
#   0:07 Spice bloom: Add green chilies (if using) and all spices. Stir 30 seconds until fragrant.
#   0:09 Tomato base: Add crushed tomatoes; simmer 5–7 minutes until slightly thickened.
#   0:14 Chickpeas: Stir in chickpeas and 1/4 cup water. Simmer 10–15 minutes to meld flavors. Adjust salt.
#   0:29 Finish: Finish with cilantro and lemon. Serve with basmati rice or naan.
#
# If you’d like, tell me:
# - Which option you want to start with (Chana Masala, Paneer Bhurji, or a vegetarian version of the chicken curry),
# - Your spice level (mild, medium, hot),
# - Any dietary needs (vegan, dairy-free, gluten-free),
# - What you have in your kitchen right now.
#
# I’ll tailor the recipe and can provide a shorter 20–25 minute version or a detailed 30-minute plan with exact measurements for your setup.
# AIMessageChunk(content='Love this lineup. I can tailor any of these to your dietary needs (vegetarian, vegan, dairy-free, gluten-free) and spice level, and I can give you a fast 30-minute plan with exact measurements. Since you’re focusing on vegetarian options, here are quick, ready-to-go picks from your list, plus a simple adaptation if you want a vegan version of Paneer Bhurji.\n\nBest vegetarian fits from your list\n- Chana Masala (Chickpea Curry) — vegan by default, gluten-free if your pantry labels are clean. Great for a straight-up flavorful, pantry-friendly meal.\n- Paneer Bhurji (Scrambled Paneer) — vegetarian. If you want dairy-free, I can show you a gentle substitution that keeps the technique and texture similar.\n\nVegetarian adaptations and quick swaps\n- Dairy-free / vegan option for Paneer Bhurji:\n  - Substitute paneer with crumbled firm tofu (same amount, 200–250 g). Sauté with the onion and spices; the texture will be slightly softer but still satisfying.\n  - Omit yogurt or cream. If you want extra creaminess, you can stir in a little non-dairy yogurt or a spoon of cashew cream at the end.\n\n- If you want to keep it fully vegetarian but lean toward a “meatier” curry (without chicken):\n  - You can swap chicken in the Simple Chicken Curry for chickpeas or potatoes and add extra vegetables (cauliflower, peas). It keeps the same curry base, just plant-based.\n\nWould you like me to tailor one of these to your spice level, any dietary needs, or ingredients you already have? I can also give you a single ultra-simple 30-minute plan with exact measurements for your first attempt.\n\nUltra-simple 30-minute plan: Chana Masala (vegan, serves 4)\n- Ingredients\n  - 1 tablespoon oil\n  - 1 small onion, finely chopped\n  - 2 cloves garlic, minced\n  - 1 inch fresh ginger, grated\n  - 1–2 green chilies, optional\n  - 1 teaspoon ground cumin\n  - 1 teaspoon ground coriander\n  - 1/2 teaspoon turmeric\n  - 1/2 teaspoon garam masala\n  - 1/2 teaspoon chili powder (adjust to taste)\n  - 1 can (400 g) chickpeas, drained and rinsed\n  - 1 cup crushed tomatoes (or 2 fresh tomatoes, chopped)\n  - Salt to taste\n  - Fresh cilantro and a squeeze of lemon to finish\n  - 1/4 cup water (more as needed)\n- Steps and timing (about 30 minutes total)\n  0:00 Prep: chop onion, mince garlic, grate ginger, rinse chickpeas.\n  0:05 Sauté: Heat oil in a pan over medium heat. Add onion; cook until soft (about 5 minutes). Add garlic and ginger; cook 1 minute.\n  0:07 Spice bloom: Add green chilies (if using) and all spices. Stir 30 seconds until fragrant.\n  0:09 Tomato base: Add crushed tomatoes; simmer 5–7 minutes until slightly thickened.\n  0:14 Chickpeas: Stir in chickpeas and 1/4 cup water. Simmer 10–15 minutes to meld flavors. Adjust salt.\n  0:29 Finish: Finish with cilantro and lemon. Serve with basmati rice or naan.\n\nIf you’d like, tell me:\n- Which option you want to start with (Chana Masala, Paneer Bhurji, or a vegetarian version of the chicken curry),\n- Your spice level (mild, medium, hot),\n- Any dietary needs (vegan, dairy-free, gluten-free),\n- What you have in your kitchen right now.\n\nI’ll tailor the recipe and can provide a shorter 20–25 minute version or a detailed 30-minute plan with exact measurements for your setup.')
